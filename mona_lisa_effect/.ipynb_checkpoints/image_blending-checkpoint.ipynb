# %%
import cv2
import math
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
from skimage.transform import resize

# %%
image = plt.imread("media/standardized_ss.png")
plt.imshow(image)
plt.show()

# %%
from numpy import load
prefiction_video = load("data/predictions_data_standardized_ss.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2b086af461ff> in <module>
#       1 from numpy import load
# ----> 2 prefiction_video = load("data/predictions_data_standardized_ss.npy")
#
# ~/miniforge3/envs/tfmac/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/predictions_data_standardized_ss.npy'
